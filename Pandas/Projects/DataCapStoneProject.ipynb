# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Countries.csv")

# %%
df.shape
# Out:
# (194, 64)

# %%
df
# Out:
#                 country                             country_long  \
# 0           Afghanistan             Islamic State of Afghanistan
# 1               Albania                      Republic of Albania
# 2               Algeria  People's Democratic Republic of Algeria
# 3               Andorra                  Principality of Andorra
# 4                Angola              People's Republic of Angola
# ..                  ...                                      ...
# 189             Vietnam            Socialist Republic of Vietnam
# 190  West Bank and Gaza                       West Bank and Gaza
# 191               Yemen                        Republic of Yemen
# 192              Zambia                       Republic of Zambia
# 193            Zimbabwe                     Republic of Zimbabwe
#
#                currency      capital_city              region continent  \
# 0        Afghan afghani             Kabul       Southern Asia      Asia
# ...

# %%
df.columns
# Out:
# Index(['country', 'country_long', 'currency', 'capital_city', 'region',
#        'continent', 'demonym', 'latitude', 'longitude', 'agricultural_land',
#        'forest_area', 'land_area', 'rural_land', 'urban_land',
#        'central_government_debt_pct_gdp', 'expense_pct_gdp', 'gdp',
#        'inflation', 'self_employed_pct', 'tax_revenue_pct_gdp',
#        'unemployment_pct', 'vulnerable_employment_pct',
#        'electricity_access_pct', 'alternative_nuclear_energy_pct',
#        'electricty_production_coal_pct',
#        'electricty_production_hydroelectric_pct',
#        'electricty_production_gas_pct', 'electricty_production_nuclear_pct',
#        'electricty_production_oil_pct', 'electricty_production_renewable_pct',
#        'energy_imports_pct', 'fossil_energy_consumption_pct',
#        'renewable_energy_consumption_pct', 'co2_emissions',
#        'methane_emissions', 'nitrous_oxide_emissions',
#        'greenhouse_other_emissions', 'urban_population_under_5m',
# ...

# %%
df[df['population'] == df['population'].max()]['country']
# Out:
# 75    India
# Name: country, dtype: object

# %%
df[df['population'] == df['population'].max()]['capital_city']
# Out:
# 75    New Delhi
# Name: capital_city, dtype: object

# %%
df[df['population'] == df['population'].min()]['country']
# Out:
# 179    Tuvalu
# Name: country, dtype: object

# %%
df[df['population'] == df['population'].min()]['capital_city']
# Out:
# 179    Funafuti
# Name: capital_city, dtype: object

# %%
df[df['democracy_score'] == df['democracy_score'].min()][['capital_city','democracy_score']]
# Out:
#             capital_city  democracy_score
# 3       Andorra la Vella              0.0
# 5           Saint John's              0.0
# 13            Bridgetown              0.0
# 16              Belmopan              0.0
# 23   Bandar Seri Begawan              0.0
# 48                Roseau              0.0
# 66          St. George's              0.0
# 87          South Tarawa              0.0
# 97                 Vaduz              0.0
# 103                 Malé              0.0
# 106               Majuro              0.0
# 110              Palikir              0.0
# 112               Monaco              0.0
# 119                Yaren              0.0
# 130            Ngerulmud              0.0
# 142                 Apia              0.0
# 143   City of San Marino              0.0
# 144             São Tomé              0.0
# 148             Victoria              0.0
# 153              Honiara              0.0
# 154            Mogadishu              0.0
# ...

# %%
df.nsmallest(5,'democracy_score')[['country','democracy_score']]
# Out:
#                 country  democracy_score
# 3               Andorra              0.0
# 5   Antigua and Barbuda              0.0
# 13             Barbados              0.0
# 16               Belize              0.0
# 23               Brunei              0.0

# %%
df.nlargest(5,'democracy_score')[['country','democracy_score']]
# Out:
#          country  democracy_score
# 127       Norway             9.87
# 74       Iceland             9.58
# 164       Sweden             9.39
# 122  New Zealand             9.26
# 46       Denmark             9.22

# %%
df['region'].nunique()
# Out:
# 22

# %%
df['region'].value_counts()
# Out:
# region
# Eastern Africa               17
# Western Asia                 17
# Western Africa               16
# Southern Europe              15
# Caribbean                    13
# South America                12
# South-Eastern Asia           11
# Northern Europe              10
# Middle Africa                10
# Eastern Europe               10
# Western Europe                9
# Southern Asia                 9
# Central America               8
# Northern Africa               6
# Micronesia                    5
# Southern Africa               5
# Eastern Asia                  5
# Central Asia                  5
# Melanesia                     4
# Polynesia                     3
# Australia and New Zealand     2
# Northern America              2
# Name: count, dtype: int64

# %%
df[df['region'] == 'Eastern Europe'].shape[0]
# Out:
# 10

# %%
(df['region'] == 'Eastern Europe').sum()
# Out:
# np.int64(10)

# %%
df[df['region'] == 'Eastern Europe']['country'].nunique()
# Out:
# 10

# %%
df[df['population'] == df['population'].max()]['political_leader']
# Out:
# 75    Narendra Modi
# Name: political_leader, dtype: object

# %%
df.nlargest(2,'population').iloc[1][['country','political_leader']]
# Out:
# country                  China
# political_leader    Xi Jinping
# Name: 34, dtype: object

# %%
df[df['political_leader'].isna()]['country'].count()
# Out:
# np.int64(7)

# %%
df[df['region'] == 'Eastern Africa'].nlargest(1, 'population')[['country', 'population']]
# Out:
#      country  population
# 57  Ethiopia   123379924

# %%
df[df['region'] == 'Eastern Africa']['population'].max()
# Out:
# 123379924
